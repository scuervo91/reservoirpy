# %%
import os
path = os.path.join('/home/santiago/Documents/dev/reservoirpy')
import sys
sys.path.insert(0,path)
import pandas as pd
import numpy as np
from reservoirpy.wellproductivitypy import pi
from reservoirpy.pvtpy import black_oil as bl
import matplotlib.pyplot as plt

# %% [markdown]
# # Potential Energy Change

# %%
#Downward flow
z1 = 0
z2 = -1900
ge = 1
angle = 0
p1 = 750
delta, p2 = pi.potential_energy_change(
    z1=z1,
    z2=z2,
    ge= ge,
    angle= angle,
    p1 = p1
)

print(delta)
print(p2)
# Out:
# [822.7]
# [1572.7]

# %%
#upward flow
z1 = -5820
z2 = 0
ge = 0.895
angle = 0
p1 = 2500
delta, p2 = pi.potential_energy_change(
    z1=z1,
    z2=z2,
    ge= ge,
    angle= angle,
    p1 = p1
)

print(delta)
print(p2)
# Out:
# [-2255.4537]
# [244.5463]

# %%
#downward flow
l= 5820
ge = 0.895
angle = -88
p1 = 10000
delta, p2 = pi.potential_energy_change(
    length=l,
    ge= ge,
    angle= angle,
    p1 = p1
)

print(delta)
print(p2)
# Out:
# [-2254.07973855]
# [7745.92026145]

# %% [markdown]
# # Kinetic Energy Change

# %%
d1 = 2.7
d2 = 1
rate = 2000
ge = 0.9294

delta, p2 = pi.kinetic_energy_change(
    d1=d1,
    d2=d2,
    rate=rate,
    ge=ge,
    p1 = 100
)

print(delta)
print(p2)
# Out:
# [-3.48248135]
# [96.51751865]

# %% [markdown]
# # Frictional Pressure Drop

# %%
rate = 1000
eps = 0.001
mu = 1.2
d = 2.259
ge = 1.04967
l = 1000

delta = pi.frictional_pressure_drop(
    rate=rate,
    epsilon = eps,
    ge = ge,
    d = d,
    mu = mu,
    length = l
)

print(delta)
# Out:
# [-5.18308727]

# %%
md = (np.linspace(0,5820,25)*-1)[::-1]
p1 = 3500
ge=.89
d = [2.7]*10 + [2.6]*5 + [2.7]*10
rate = 1000
mu = 11.3
epsilon = 0.001

pf = pi.incompressible_pressure_profile(
    p1=p1,
    ge=ge,
    epsilon=epsilon,
    md=md,
    tvd=md,
    d = d,
    rate = rate,
    mu=mu
    )
pf
# Out:
#         md     tvd  diameter     pressure        ppe       pke        pf  \
# 0  -5820.0 -5820.0       2.7  3500.000000   0.000000  0.000000  0.000000
# 1  -5577.5 -5577.5       2.7  3405.759477 -93.452225  0.000000 -0.788298
# 2  -5335.0 -5335.0       2.7  3311.518954 -93.452225  0.000000 -0.788298
# 3  -5092.5 -5092.5       2.7  3217.278430 -93.452225  0.000000 -0.788298
# 4  -4850.0 -4850.0       2.7  3123.037907 -93.452225  0.000000 -0.788298
# 5  -4607.5 -4607.5       2.7  3028.797384 -93.452225  0.000000 -0.788298
# 6  -4365.0 -4365.0       2.7  2934.556861 -93.452225  0.000000 -0.788298
# 7  -4122.5 -4122.5       2.7  2840.316337 -93.452225  0.000000 -0.788298
# 8  -3880.0 -3880.0       2.7  2746.075814 -93.452225  0.000000 -0.788298
# 9  -3637.5 -3637.5       2.7  2651.835291 -93.452225  0.000000 -0.788298
# 10 -3395.0 -3395.0       2.6  2557.438853 -93.452225 -0.002605 -0.941608
# 11 -3152.5 -3152.5       2.6  2463.045020 -93.452225  0.000000 -0.941608
# 12 -2910.0 -2910.0       2.6  2368.651188 -93.452225  0.000000 -0.941608
# 13 -2667.5 -2667.5       2.6  2274.257355 -93.452225  0.000000 -0.941608
# 14 -2425.0 -2425.0       2.6  2179.863522 -93.452225  0.000000 -0.941608
# 15 -2182.5 -2182.5       2.7  2085.625604 -93.452225  0.002605 -0.788298
# 16 -1940.0 -1940.0       2.7  1991.385081 -93.452225  0.000000 -0.788298
# 17 -1697.5 -1697.5       2.7  1897.144558 -93.452225  0.000000 -0.788298
# 18 -1455.0 -1455.0       2.7  1802.904035 -93.452225  0.000000 -0.788298
# 19 -1212.5 -1212.5       2.7  1708.663511 -93.452225  0.000000 -0.788298
# 20  -970.0  -970.0       2.7  1614.422988 -93.452225  0.000000 -0.788298
# 21  -727.5  -727.5       2.7  1520.182465 -93.452225  0.000000 -0.788298
# 22  -485.0  -485.0       2.7  1425.941942 -93.452225  0.000000 -0.788298
# 23  -242.5  -242.5       2.7  1331.701418 -93.452225  0.000000 -0.788298
# 24    -0.0    -0.0       2.7  1237.460895 -93.452225  0.000000 -0.788298
#
#       delta_p
# 0    0.000000
# 1  -94.240523
# 2  -94.240523
# 3  -94.240523
# 4  -94.240523
# 5  -94.240523
# 6  -94.240523
# 7  -94.240523
# 8  -94.240523
# 9  -94.240523
# 10 -94.396438
# 11 -94.393833
# 12 -94.393833
# 13 -94.393833
# 14 -94.393833
# 15 -94.237918
# 16 -94.240523
# 17 -94.240523
# 18 -94.240523
# 19 -94.240523
# 20 -94.240523
# 21 -94.240523
# 22 -94.240523
# 23 -94.240523
# 24 -94.240523

# %% [markdown]
# # Flow Regime

# %%
#Flow Regime

ql = 200 # bbl/2
ge = 1 
qg = 10000 # ft3
st = 74

fig, ax= plt.subplots(figsize=(12,7))
pi.flow_regime_plot(
    ql=ql, 
    qg=qg,
    d=2.00,
    sg_liquid = ge,
    surface_tension=st,
    ann=True,
    ax=ax
    )

# %%
#Flow Regime

ql = 200 # bbl/2
ge = 1 
qg = 10000 # ft3
st = 74

fig, ax= plt.subplots(figsize=(12,7))
pi.flow_regime_plot(
    ql=ql, 
    qg=qg,
    d=2.00,
    sg_liquid = ge,
    surface_tension=st,
    ann=True,
    ax=ax,
    method='taitel_dukler'
    )

# %% [markdown]
# # Multiphase Pressure Gradient Correlations

# %%
gradient = pi.hb_correlation(
    pressure=800,  #Pressure [psi]
    temperature=175, #Temperature [F]
    liquid_rate=2000, # Liquid Flow [bbl/d]
    gas_rate=1000, # gas flow [kscfd]
    ten_liquid=30, #Surface tension dyne/cm2
    rho_liquid=49.8, # density lb/ft3
    rho_gas=2.6, # density lb/ft3
    mu_liquid=2.0, # Viscosity [cp]
    mu_gas=0.0131, # Viscosity [cp]
    z=0.935, # Gas compressibility Factor
    di=2.259, # Diameter,
    epsilon = 0.0006)
    
print(gradient)
# Out:
# [0.19198487]

# %%
#Gas
composition = {
    'mole_fraction':[0.02,0.01,0.85,0.04,0.03,0.03,0.02]
    }


chrom=bl.chromatography(composition, compound=['carbon-dioxide','nitrogen','methane','ethane','propane','isobutane','n-butane'])
fm = 'fm_1'
t= 210
gas = bl.gas(formation=fm, temp=t, chromatography=chrom)
gas.pvt_from_correlations()

# %%
#water pvt
water = bl.water(formation='fm_1',pb=2000,salinity=13500, temp=60)
water.pvt_from_correlations()
water.pvt['tension']=30

# %%
#oil pvt
oil = bl.oil(formation='fm_1',api=31,rsb=675,sg_gas=0.95,temp=180)
oil.pvt_from_correlations()
oil.pvt['tension']=30

# %%
pr, pwf= pi.two_phase_pressure_profile(
    depth = np.linspace(0,5820,30),
    thp = 800,
    liquid_rate = 2000,
    oil_rate = None,
    gas_rate = 1000,
    glr = None,
    gor = None,
    bsw = 0.0,
    oil_obj = oil,
    gas_obj = gas,
    water_obj = water, 
    epsilon=0.0006, 
    surface_temperature=80, 
    temperature_gradient=1,  
    di=2.99, 
    tol=0.008,
    max_iter = 20,
    method = 'hagedorn_brown',
)


print(pwf)
#print(pr)
# Out:
# 2682.680722057234

# %%
pr
# Out:
#                 pressure  pressure_gradient  free_gas_rate  temperature  \
# 0.000000      800.000000           0.330198       0.000000    80.000000
# 200.689655    855.888109           0.277253     315.154620    82.006897
# 401.379310    912.764426           0.283539     291.420233    84.013793
# 602.068966    970.820534           0.289398     267.193522    86.020690
# 802.758621   1029.972730           0.294842     242.509414    88.027586
# 1003.448276  1091.768243           0.308014     217.063490    90.034483
# 1204.137931  1154.271523           0.311480     191.894507    92.041379
# 1404.827586  1217.408169           0.314629     166.470479    94.048276
# 1605.517241  1281.117639           0.317477     140.815784    96.055172
# 1806.206897  1344.832034           0.320020     115.234815    98.062069
# 2006.896552  1409.056679           0.322296      89.712562   100.068966
# 2207.586207  1473.738058           0.324330      64.008807   102.075862
# 2408.275862  1538.827706           0.326138      38.142810   104.082759
# 2608.965517  1604.280175           0.327736      12.134407   106.089655
# 2809.655172  1670.053499           0.329387     -13.993247   108.096552
# 3010.344828  1736.157990           0.331051     -40.252453   110.103448
# 3211.034483  1802.596438           0.332533     -66.644320   112.110345
# 3411.724138  1869.332432           0.333852     -93.197292   114.117241
# 3612.413793  1936.333000           0.335035    -120.009425   116.124138
# 3813.103448  2003.571028           0.336066    -146.916583   118.131034
# 4013.793103  2071.015951           0.336953    -173.906536   120.137931
# 4214.482759  2138.638888           0.337718    -201.074784   122.144828
# 4415.172414  2206.415427           0.338385    -228.530332   124.151724
# 4615.862069  2274.325884           0.338932    -256.040129   126.158621
# 4816.551724  2342.346011           0.339364    -283.594352   128.165517
# 5017.241379  2410.452907           0.339462    -304.621041   130.172414
# 5217.931034  2478.579462           0.339248    -318.027441   132.179310
# 5418.620690  2546.663048           0.339008    -331.425385   134.186207
# 5619.310345  2614.698420           0.338743    -344.813842   136.193103
# 5820.000000  2682.680722           0.337935    -350.000000   138.200000
#
#              iterations
# 0.000000            0.0
# 200.689655          2.0
# 401.379310          2.0
# 602.068966          2.0
# 802.758621          2.0
# 1003.448276         3.0
# 1204.137931         2.0
# 1404.827586         2.0
# 1605.517241         2.0
# 1806.206897         1.0
# 2006.896552         1.0
# 2207.586207         1.0
# 2408.275862         1.0
# 2608.965517         1.0
# 2809.655172         1.0
# 3010.344828         1.0
# 3211.034483         1.0
# 3411.724138         1.0
# 3612.413793         1.0
# 3813.103448         1.0
# 4013.793103         1.0
# 4214.482759         1.0
# 4415.172414         1.0
# 4615.862069         1.0
# 4816.551724         1.0
# 5017.241379         1.0
# 5217.931034         1.0
# 5418.620690         1.0
# 5619.310345         1.0
# 5820.000000         1.0

# %%
df = pi.two_phase_outflow_curve(
    depth = np.linspace(0,5820,30),
    thp = [800],
    liquid_rate = np.linspace(5,3000,10),
    oil_rate = None,
    gas_rate = None,
    glr = [200,500,700,1000],
    gor = None,
    bsw = [0.3],
    oil_obj = oil,
    gas_obj = gas,
    water_obj = water, 
    epsilon=0.0006, 
    surface_temperature=80, 
    temperature_gradient=1,  
    di=2.99, 
    tol=0.008,
    max_iter = 20,
    method = 'hagedorn_brown',
)
fig, ax = plt.subplots(figsize=(13,7))
df.plot(ax=ax)
# Out:
# 0
# bsw_0.3 glr_200 thp_800 di_2.99
# 1
# bsw_0.3 glr_500 thp_800 di_2.99
# 2
# bsw_0.3 glr_700 thp_800 di_2.99
# 3
# bsw_0.3 glr_1000 thp_800 di_2.99
